# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel(r'C:\my folder\Copy of Online Retail.xlsx')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
 df[df.isna().any(axis=1)]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (406829, 8)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df['InvoiceNo']=='C541433']
df= df.drop(61624)

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
frequency = df.groupby("CustomerID").agg({"InvoiceDate":"nunique"}).rename(columns={'InvoiceDate': 'Frequency'})
frequency
# Out:
#             Frequency
# CustomerID
# 12346.0             1
# 12347.0             7
# 12348.0             4
# 12349.0             1
# 12350.0             1
# ...               ...
# 18280.0             1
# 18281.0             1
# 18282.0             3
# 18283.0            16
# 18287.0             3
#
# [4372 rows x 1 columns]

# %%
df.groupby('CustomerID')['InvoiceNo'].count()
# Out:
# CustomerID
# 12346.0      1
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
#           ...
# 18280.0     10
# 18281.0      7
# 18282.0     13
# 18283.0    756
# 18287.0     70
# Name: InvoiceNo, Length: 4372, dtype: int64

# %%
df['duration'] = df['InvoiceDate'].max()-df['InvoiceDate']
df['Recency'] = df['duration'].dt.days

# %%
recency = pd.DataFrame(df.groupby('CustomerID')['Recency'].min())
recency
# Out:
#             Recency
# CustomerID
# 12346.0         325
# 12347.0           1
# 12348.0          74
# 12349.0          18
# 12350.0         309
# ...             ...
# 18280.0         277
# 18281.0         180
# 18282.0           7
# 18283.0           3
# 18287.0          42
#
# [4372 rows x 1 columns]

# %%
df['Monetary']=df['Quantity']*df['UnitPrice']
monetary = pd.DataFrame(df.groupby('CustomerID')['Monetary'].sum())

# %%
rfm = pd.concat([frequency, monetary, recency], axis=1)
rfm.head()
# Out:
#             Frequency  Monetary  Recency
# CustomerID
# 12346.0             1  77183.60      325
# 12347.0             7   4310.00        1
# 12348.0             4   1797.24       74
# 12349.0             1   1757.55       18
# 12350.0             1    334.40      309

# %%
plt.boxplot(rfm['Monetary'])
plt.show()
plt.boxplot(rfm['Frequency'])
plt.show()
plt.boxplot(rfm['Recency'])
plt.show()

# %%
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data = rfm[['Monetary','Recency','Frequency']], orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
# Out:
# <AxesSubplot:>

# %%
rfm
# Out:
#             Frequency  Monetary  Recency
# CustomerID
# 12346.0             1  77183.60      325
# 12347.0             7   4310.00        1
# 12348.0             4   1797.24       74
# 12349.0             1   1757.55       18
# 12350.0             1    334.40      309
# ...               ...       ...      ...
# 18280.0             1    180.60      277
# 18281.0             1     80.82      180
# 18282.0             3    176.60        7
# 18283.0            16   2094.88        3
# 18287.0             3   1837.28       42
#
# [4372 rows x 3 columns]

# %%
q1 = rfm['Monetary'].quantile(0.05)
q3 = rfm['Monetary'].quantile(0.95)
IQR = q3-q1
rfm_new= rfm[(rfm['Monetary']>=q1) & (rfm['Monetary']<=q3)]

q_1 = rfm['Frequency'].quantile(0.05)
q_3 = rfm['Frequency'].quantile(0.95)
rfm_new = rfm[(rfm['Frequency']>=q_1) & (rfm['Frequency']<=q_3)]

qt1 = rfm['Recency'].quantile(0.05)
qt3 = rfm['Recency'].quantile(0.95)
rfm_new = rfm[(rfm['Recency']>=qt1) & (rfm['Recency']<=qt3)]

rfm_new
rfm_without_outlier = rfm_new
rfm_without_outlier
# Out:
#             Frequency  Monetary  Recency
# CustomerID
# 12348.0             4   1797.24       74
# 12349.0             1   1757.55       18
# 12350.0             1    334.40      309
# 12352.0            11   1545.41       35
# 12353.0             1     89.00      203
# ...               ...       ...      ...
# 18280.0             1    180.60      277
# 18281.0             1     80.82      180
# 18282.0             3    176.60        7
# 18283.0            16   2094.88        3
# 18287.0             3   1837.28       42
#
# [3961 rows x 3 columns]

# %%
rfm_new.iloc[0]['Recency']    # getting elements from the 'Recency' column
rfm_new.iloc[0,2]
# Out:
# 74

# %%
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
rfm_scaled = scaler.fit_transform(rfm_new)
rfm_scaled
# Out:
# array([[-0.09079625,  0.02919894, -0.09068457],
#        [-0.57944294,  0.02193967, -0.75503782],
#        [-0.57944294, -0.23835318,  2.6972264 ],
#        ...,
#        [-0.25367848, -0.26721466, -0.88553578],
#        [ 1.8637905 ,  0.08363702, -0.93298958],
#        [-0.25367848,  0.03652222, -0.47031499]])

# %%
def group(Q1,Q3,Q4,value):
    if value<=Q1:
        return '1'
    if Q1< value <=Q3:
        return '2'
    if Q3<value<=Q4:
        return '3'
    if Q4<value:
        return '4'

# %%
rec_q1,rec_q2,rec_q3 = rfm['Recency'].quantile([0.25,.050,0.75])

# %%
recency_group =[]
for i in range(len(rfm)):
    rece = rfm.iloc[i]['Recency']
    recency_group.append(group(rec_q1,rec_q2,rec_q3,rece))

rfm['recency_group'] = recency_group

# %%
freq_q1,freq_q2,freq_q3= rfm['Frequency'].quantile([0.25,0.50,0.75])

# %%
freq_group = []
for i in range(len(rfm)):
    freq = rfm.iloc[i]['Frequency']
    freq_group.append(group(freq_q1,freq_q2,freq_q3,freq))
rfm['freq_group']= freq_group

# %%
mon_q1,mon_q2,mon_q3 = rfm['Monetary'].quantile([0.25,0.50,0.75])

# %%
mon_group=[]
for i in range(len(rfm)):
    mon= rfm.iloc[i]['Monetary']
    mon_group.append(group(mon_q1,mon_q2,mon_q3,mon))
rfm['mon_group']=mon_group

# %%
rfm
# Out:
#             Frequency  Monetary  Recency recency_group freq_group mon_group
# CustomerID
# 12346.0             1  77183.60      325             4          1         4
# 12347.0             7   4310.00        1             1          4         4
# 12348.0             4   1797.24       74             3          3         4
# 12349.0             1   1757.55       18             3          1         4
# 12350.0             1    334.40      309             4          1         2
# ...               ...       ...      ...           ...        ...       ...
# 18280.0             1    180.60      277             4          1         1
# 18281.0             1     80.82      180             4          1         1
# 18282.0             3    176.60        7             1          2         1
# 18283.0            16   2094.88        3             1          4         4
# 18287.0             3   1837.28       42             3          2         4
#
# [4372 rows x 6 columns]

# %%
rfm['score']=rfm['recency_group'].astype(str)+rfm['freq_group'].astype(str)+rfm['mon_group'].astype(str)

# %%
rfm['final score']= rfm['recency_group'].astype(int)+rfm['freq_group'].astype(int)+rfm['mon_group'].astype(int)

# %%
rfm
# Out:
#             Frequency  Monetary  Recency recency_group freq_group mon_group  \
# CustomerID
# 12346.0             1  77183.60      325             4          1         4
# 12347.0             7   4310.00        1             1          4         4
# 12348.0             4   1797.24       74             3          3         4
# 12349.0             1   1757.55       18             3          1         4
# 12350.0             1    334.40      309             4          1         2
# ...               ...       ...      ...           ...        ...       ...
# 18280.0             1    180.60      277             4          1         1
# 18281.0             1     80.82      180             4          1         1
# 18282.0             3    176.60        7             1          2         1
# 18283.0            16   2094.88        3             1          4         4
# 18287.0             3   1837.28       42             3          2         4
#
#            score  final score
# CustomerID
# ...

# %%
customer_segment = ['Platinum','Diamond','Gold','Silver']
sgmt= pd.qcut(rfm['final score'], q=4, labels = customer_segment)
rfm['Segment']=sgmt.values
rfm
# Out:
#             Frequency  Monetary  Recency recency_group freq_group mon_group  \
# CustomerID
# 12346.0             1  77183.60      325             4          1         4
# 12347.0             7   4310.00        1             1          4         4
# 12348.0             4   1797.24       74             3          3         4
# 12349.0             1   1757.55       18             3          1         4
# 12350.0             1    334.40      309             4          1         2
# ...               ...       ...      ...           ...        ...       ...
# 18280.0             1    180.60      277             4          1         1
# 18281.0             1     80.82      180             4          1         1
# 18282.0             3    176.60        7             1          2         1
# 18283.0            16   2094.88        3             1          4         4
# 18287.0             3   1837.28       42             3          2         4
#
#            score  final score   Segment
# ...

# %%
def seg_group(score):
    if score =='144':
        return 'Best Customer'
    elif score =='411':
        return 'Beginner'
    elif score  =='444':
        return 'Lost Big Spender'
    elif score  == '441':
        return 'Lost Cheap'
    elif score[1] =='4':
        return 'Loyal'
    elif score[2] =='4':
        return 'Big Spender'
    else :
        return 'Normal Customer'

# %%
rfm['c_segment']= rfm.score.apply(seg_group)

# %%
rfm
# Out:
#             Frequency  Monetary  Recency recency_group freq_group mon_group  \
# CustomerID
# 12346.0             1  77183.60      325             4          1         4
# 12347.0             7   4310.00        1             1          4         4
# 12348.0             4   1797.24       74             3          3         4
# 12349.0             1   1757.55       18             3          1         4
# 12350.0             1    334.40      309             4          1         2
# ...               ...       ...      ...           ...        ...       ...
# 18280.0             1    180.60      277             4          1         1
# 18281.0             1     80.82      180             4          1         1
# 18282.0             3    176.60        7             1          2         1
# 18283.0            16   2094.88        3             1          4         4
# 18287.0             3   1837.28       42             3          2         4
#
# ...
